# %%
# %matplotlib inline

# %%
# import dependencies
import pandas as pd
from pandas.plotting import scatter_matrix

import matplotlib as mlp
from matplotlib import pyplot as plt

from sklearn.impute import SimpleImputer

# %%
life_expectancy_df = pd.read_csv("data/Life Expectancy Data.csv")
life_expectancy_df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
# inspect data types and check for null-values using pandas info method
life_expectancy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
# examine column names (look for extra spacing)
life_expectancy_df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
# remove extra space from "Life expectancy " using pandas rename
life_expectancy_df.rename(columns={
    "Life expectancy ": "Life_Exp",
    "Measles ": "Measles",
    " BMI ": "BMI",
    "under-five deaths ": "under-five deaths",
    "Diphtheria ": "Diphtheria",
    " HIV/AIDS": "HIV/AIDS",
    " thinness  1-19 years": "thinness 1-19 years",
    " thinness 5-9 years": "thinness 5-9 years"
}, inplace=True)

life_expectancy_df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness 1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
# df['DataFrame Column'] = pd.to_datetime(df['DataFrame Column'], format=specify your format)
life_expectancy_df['Year'] = pd.to_datetime(life_expectancy_df['Year'], format='%Y', errors='coerce')

life_expectancy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   datetime64[ns]
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
# ...

# %%
life_expectancy_df["gdpPercap"] = life_expectancy_df['GDP'] / life_expectancy_df['Population']

# %%
life_expectancy_df.describe()
# Out:
#        Life expectancy  Adult Mortality  infant deaths      Alcohol  \
# count      2768.000000      2768.000000    2775.000000  2590.000000
# mean         69.349566       163.041546      29.293333     4.513212
# std           9.360784       122.954439     120.112491     4.008508
# min          36.300000         1.000000       0.000000     0.010000
# 25%          63.500000        73.000000       0.000000     0.830000
# 50%          72.200000       143.500000       3.000000     3.690000
# 75%          75.500000       225.000000      20.000000     7.490000
# max          89.000000       723.000000    1800.000000    17.870000
#
#        percentage expenditure  Hepatitis B        Measles          BMI  \
# count             2775.000000  2266.000000    2775.000000  2742.000000
# mean               781.615245    80.895852    2189.796757    38.569256
# std               2037.181162    25.016863   10542.603258    19.921767
# ...

# %%
# review distribution of each "feature" using .hist method
life_expectancy_df.hist(bins=50, figsize=(25,20))
plt.show()

# %%
# examine correlations 
corr_matrix = life_expectancy_df.corr()

# examine how each attribute correlates with life expectancy
# note corr only meaures linear correclations
corr_matrix["Life expectancy"].sort_values(ascending=False) # sort in descending order
# Out:
# Life expectancy                    1.000000
# Schooling                          0.751975
# Income composition of resources    0.724776
# BMI                                0.567694
# Diphtheria                         0.479495
# Polio                              0.465556
# GDP                                0.461455
# Alcohol                            0.404877
# percentage expenditure             0.381864
# Hepatitis B                        0.256762
# Total expenditure                  0.218086
# Population                        -0.021538
# Measles                           -0.157586
# infant deaths                     -0.196557
# under-five deaths                 -0.222529
# thinness 5-9 years                -0.471584
# thinness 1-19 years               -0.477183
# HIV/AIDS                          -0.556556
# Adult Mortality                   -0.696359
# Name: Life expectancy, dtype: float64

# %%
# create a short list of attributes to examine using scatter_matrix method
attributes = [
    'Life expectancy',
    'Schooling',
    'Income composition of resources',
    'BMI',
    'GDP',
    'percentage expenditure',
    'Population', 
    'infant deaths'
]

# %%
# examine scatter plot of numberical attribute agains every other  numerical attibute
scatter_matrix(life_expectancy_df[attributes], figsize=(25,20), diagonal='kde')
plt.show()

# %%
# look again for missing values
life_expectancy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2768 entries, 0 to 2937
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2768 non-null   object
#  1   Year                             2768 non-null   datetime64[ns]
#  2   Status                           2768 non-null   object
#  3   Life expectancy                  2768 non-null   float64
#  4   Adult Mortality                  2768 non-null   float64
#  5   infant deaths                    2768 non-null   int64
#  6   Alcohol                          2584 non-null   float64
#  7   percentage expenditure           2768 non-null   float64
#  8   Hepatitis B                      2259 non-null   float64
#  9   Measles                          2768 non-null   int64
#  10  BMI                              2736 non-null   float64
# ...

# %%
# clean data by dropping nulls
life_expectancy_df.dropna(subset=["Schooling", "Life expectancy"], inplace=True)

# %%
life_expectancy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2768 entries, 0 to 2937
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2768 non-null   object
#  1   Year                             2768 non-null   datetime64[ns]
#  2   Status                           2768 non-null   object
#  3   Life expectancy                  2768 non-null   float64
#  4   Adult Mortality                  2768 non-null   float64
#  5   infant deaths                    2768 non-null   int64
#  6   Alcohol                          2584 non-null   float64
#  7   percentage expenditure           2768 non-null   float64
#  8   Hepatitis B                      2259 non-null   float64
#  9   Measles                          2768 non-null   int64
#  10  BMI                              2736 non-null   float64
# ...

# %%
# group by country
life_expectancy_df_grouped = life_expectancy_df.groupby(['Country', 'Year']).mean()
life_expectancy_df_grouped
# Out:
#                         Life expectancy  Adult Mortality  infant deaths  \
# Country     Year
# Afghanistan 2000-01-01             54.8            321.0             88
#             2001-01-01             55.3            316.0             88
#             2002-01-01             56.2              3.0             88
#             2003-01-01             56.7            295.0             87
#             2004-01-01             57.0            293.0             87
# ...                                 ...              ...            ...
# Zimbabwe    2011-01-01             54.9            464.0             28
#             2012-01-01             56.6            429.0             26
#             2013-01-01             58.0            399.0             25
#             2014-01-01             59.2            371.0             23
#             2015-01-01             67.0            336.0             22
#
#                         Alcohol  percentage expenditure  Hepatitis B  Measles  \
# ...

# %%
# save to JSON using to_json method
life_expectancy_df.to_json(orient="index")
# Out:
# '{"0":{"Country":"Afghanistan","Year":1420070400000,"Status":"Developing","Life expectancy":65.0,"Adult Mortality":263.0,"infant deaths":62,"Alcohol":0.01,"percentage expenditure":71.27962362,"Hepatitis B":65.0,"Measles":1154,"BMI":19.1,"under-five deaths":83,"Polio":6.0,"Total expenditure":8.16,"Diphtheria":65.0,"HIV\\/AIDS":0.1,"GDP":584.25921,"Population":33736494.0,"thinness 1-19 years":17.2,"thinness 5-9 years":17.3,"Income composition of resources":0.479,"Schooling":10.1},"1":{"Country":"Afghanistan","Year":1388534400000,"Status":"Developing","Life expectancy":59.9,"Adult Mortality":271.0,"infant deaths":64,"Alcohol":0.01,"percentage expenditure":73.52358168,"Hepatitis B":62.0,"Measles":492,"BMI":18.6,"under-five deaths":86,"Polio":58.0,"Total expenditure":8.18,"Diphtheria":62.0,"HIV\\/AIDS":0.1,"GDP":612.696514,"Population":327582.0,"thinness 1-19 years":17.5,"thinness 5-9 years":17.5,"Income composition of resources":0.476,"Schooling":10.0},"2":{"Country":"Afghanistan","Year"
# ...
